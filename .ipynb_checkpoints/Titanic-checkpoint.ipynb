# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import math

filename = 'titanic_data.csv'
titanic_df = pd.read_csv(filename)
transform_df = pd.read_csv(filename)
#Make a plot of your choice here showing something interesting about the titanic data.
#Matplotlib documentation here: http://matplotlib.org/api/pyplot_api.html
#Once you've got something you're happy with, share it on the forums!

# %%
## Check for missing values
missing_values_df = pd.DataFrame(titanic_df.isnull().sum()/titanic_df.shape[0])
missing_values_df.index.name = 'Feature'
missing_values_df.columns = ['missing_pct']
missing_values_df.sort_values(['missing_pct'], ascending=[False], inplace=True)

ax = missing_values_df[['missing_pct']].plot(kind='bar', title ="Check for missing values", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Feature", fontsize=12)
ax.set_ylabel("missing_pct", fontsize=12)
plt.show()

# %%
yoda_df = missing_values_df[missing_values_df['missing_pct'] > 0]

ax = yoda_df[['missing_pct']].plot(kind='bar', title ="Just the features missing a value percentage descending", figsize=(10, 5), legend=True, fontsize=12)
ax.set_xlabel("Feature", fontsize=12)
ax.set_ylabel("missing_pct", fontsize=12)
plt.show()

# %%
transform_df['Age'].fillna(0, inplace=True)

if False:
    print(titanic_df['Age'].head(10))
    print(transform_df['Age'].head(10))

# %%
transform_df['Embarked'].fillna('(Blanks)', inplace=True)

if False:
    print(transform_df['Embarked'].head(10))

# %%
def get_title(name):
    comma = name.find(',')
    period = name.find('.')
    title = name[comma+2:period+1]
    return title

if False:
    print(get_title('Baumann, Mr. John D'))
    print(get_title('Boulos, Mr. Hanna'))
    print(get_title('Boulos, Mrs. Joseph (Sultana)'))
    print(get_title('Bourke, Miss. Mary'))
    print(get_title('Bradley, Mr. George ("George Arthur Brayton")'))
    print(get_title('Brewe, Dr. Arthur Jackson'))

# %%
transform_df['Title'] = transform_df.apply(lambda row: get_title(row.Name), axis=1)

if False:
    print(transform_df['Title'].head(10))

# %%
title_group = transform_df.groupby('Title').size().reset_index(name='count')
title_list = title_group['Title']
for x in title_list:
    title_df = transform_df[transform_df['Title'] == x]
    agenonzero_df = title_df[title_df['Age'] != 0]
    title_age_median = np.mean(agenonzero_df['Age'])
    agezero_df = title_df[title_df['Age'] == 0]
    transform_df.loc[(transform_df['Title'] == x) & (transform_df['Age'] == 0), 'Age'] = title_age_median
    
if False:    
    print(transform_df['Age'].head(20))
    print(transform_df['Title'].head(20))

# %% [markdown]
# # Women and children first
# From Wikipedia, the free encyclopedia
# For other uses, see Women and children first (disambiguation).
#
# Thomas Hemy's famous painting (circa 1892) of soldiers standing fast on HMS Birkenhead while the women and children head off in a lifeboat in the background
# "Women and children first" (or to a lesser extent, the Birkenhead Drill[1][2]) is a code of conduct dating from 1852, whereby the lives of women and children were to be saved first in a life-threatening situation, typically abandoning ship, when survival resources such as lifeboats were limited.
#
# # Child
# From Wikipedia, the free encyclopedia
# This article is about the juvenile human. For other uses, see Child (disambiguation).
# "Children" redirects here. For other uses, see Children (disambiguation).
# Biologically, a child (plural: children) is a human being between the stages of birth and puberty.[1][2] The legal definition of child generally refers to a minor, otherwise known as a person younger than the age of majority.[1]
#
# ## Legal, biological, social definitions[edit]
#
# Children playing ball games, Roman artwork, 2nd century AD
# Legally, the term "child" may refer to anyone below the age of majority or some other age limit. The United Nations Convention on the Rights of the Child defines child as "a human being below the age of 18 years unless under the law applicable to the child, majority is attained earlier".[5] This is ratified by 192 of 194 member countries. The term "child" may also refer to someone below another legally defined age limit unconnected to the age of majority. In Singapore, for example, a "child" is legally defined as someone under the age of 14 under the "Children and Young Persons Act" whereas the age of majority is 21.[6][7] In U.S. Immigration Law, a child refers to anyone who is under the age of 21.[8]

# %%
def get_agegroup(age):
    if age < 21:
        return '1: 0-20'
    if age < 41:
        return '2: 21-40'
    if age < 61:
        return '3: 41-60'
    if age < 81:
        return '4: 61-80'
    else:
        return '5: 80+'

if False:
    print(get_agegroup(0)) 
    print(get_agegroup(55)) 
    print (get_agegroup(100))

# %%
transform_df['AgeGroup'] = transform_df.apply(lambda row: get_agegroup(row.Age), axis=1)

if False:
    print(transform_df['AgeGroup'].head(10))

# %%
def get_faregroup(fare, mean):
    intmean = int(mean)
    inthalfmean = int(mean/2)
    intdoublemean = int(mean*2)
    if fare < mean:
        if fare < (mean/2):
            return '1: 0-'+str(inthalfmean-1)
        else:
            return '2: '+str(inthalfmean)+'-'+str(intmean-1)
    if fare > mean:
        if fare < (mean*2):
            return '3: '+str(intmean)+'-'+str(intdoublemean-1)
        else:
            return '4: '+str(intdoublemean)+'+'

if False:
    print(get_faregroup(15,32.204207968574636)) 
    print(get_faregroup(31,32.204207968574636)) 
    print(get_faregroup(32,32.204207968574636)) 
    print(get_faregroup(33,32.204207968574636)) 
    print(get_faregroup(65,32.204207968574636)) 
    print (get_faregroup(32.204207968574636,32.204207968574636))

# %%
faremean = transform_df['Fare'].mean()
transform_df['FareGroup'] = transform_df.apply(lambda row: get_faregroup(row.Fare, faremean), axis=1)

if False:
    print(transform_df['FareGroup'].head(10))

# %%
transform_df['DeckLevel'] = transform_df['Cabin'].str.slice(0,1)
transform_df['DeckLevel'].fillna('(Blanks)', inplace=True)

# %%
transform_df['TicketIndex'] = transform_df['Ticket'].str.slice(0,1)

# %%
transform_df['Age'] = transform_df['Age'].round(0).astype(int)

# %%
sns.distplot(transform_df.Age.dropna())
plt.show()

# %%
g = sns.FacetGrid(transform_df, row='Survived', col='Pclass')
g.map(sns.distplot, "Age")
plt.show()

# %%
sns.jointplot(data=transform_df, x='Age', y='Fare', kind='reg', color='g')
plt.show()

# %%
sns.jointplot(data=transform_df, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()

# %%
df = transform_df.pivot_table(index='Embarked', columns='AgeGroup', values='Fare', aggfunc=np.median)
sns.heatmap(df, annot=True, fmt=".1f")

# %%
correlation_matrix = transform_df
del correlation_matrix['PassengerId']

sns.heatmap(correlation_matrix.corr(), annot=True, fmt=".2f")

# %%
dead = transform_df[transform_df['Survived'] == 0]
alive = transform_df[transform_df['Survived'] == 1]

child_alive = alive[alive['Age'] < 21]
child_dead = dead[dead['Age'] < 21]
child_female_alive = child_alive[child_alive['Gender'] == 'female']
child_female_dead = child_dead[child_dead['Gender'] == 'female']
child_male_alive = child_alive[child_alive['Gender'] == 'male']
child_male_dead = child_dead[child_dead['Gender'] == 'male']

female_alive = alive[alive['Gender'] == 'female']
female_dead = dead[dead['Gender'] == 'female']
male_alive = alive[alive['Gender'] == 'male']
male_dead = dead[dead['Gender'] == 'male']

# %%
def plot_survival_count(alive, dead, plot_title, xlabel, ylabel):
    alive_group = alive.groupby([xlabel]).size().reset_index(name='Alive')
    dead_group = dead.groupby([xlabel]).size().reset_index(name='Dead')
    
    merge_dead_and_alive = pd.merge(alive_group, dead_group, how='outer', on=xlabel)
    merge_dead_and_alive['Alive'].fillna(0, inplace=True)
    merge_dead_and_alive['Dead'].fillna(0, inplace=True)

    plot_df = merge_dead_and_alive
    plot_df.set_index(xlabel, inplace=True)
    plot_df.sort_values(['Alive'], ascending=[False], inplace=True)
    
    my_plot = plot_df.plot(kind='bar',stacked=True,title=plot_title)
    my_plot.set_xlabel(xlabel)
    my_plot.set_ylabel(ylabel)
    plt.show()

# %%
def plot_survival_rates(alive, dead, plot_title, xlabel, ylabel):
    alive_group = alive.groupby([xlabel]).size().reset_index(name='AliveCount')
    dead_group = dead.groupby([xlabel]).size().reset_index(name='DeadCount')
    merge_dead_and_alive = pd.merge(alive_group, dead_group, how='outer', on=xlabel)

    merge_dead_and_alive['AliveCount'].fillna(0, inplace=True)
    merge_dead_and_alive['DeadCount'].fillna(0, inplace=True)

    merge_dead_and_alive['Alive'] = (merge_dead_and_alive['AliveCount']/(merge_dead_and_alive['DeadCount']+merge_dead_and_alive['AliveCount']))*100
    merge_dead_and_alive['Dead'] = (merge_dead_and_alive['DeadCount']/(merge_dead_and_alive['DeadCount']+merge_dead_and_alive['AliveCount']))*100

    del merge_dead_and_alive['AliveCount']
    del merge_dead_and_alive['DeadCount']

    plot_df = merge_dead_and_alive
    plot_df.set_index(xlabel, inplace=True)
    plot_df.sort_values(['Alive'], ascending=[False], inplace=True)
    
    my_plot = plot_df.plot(kind='bar',stacked=True,title=plot_title)
    my_plot.set_xlabel(xlabel)
    my_plot.set_ylabel(ylabel)
    plt.show()

# %%
xlabel = 'Age'
plot_survival_count(child_alive, child_dead, 'child Survival Count By '+xlabel, xlabel, 'count')
plot_survival_rates(child_alive, child_dead, 'child Survival Rates By '+xlabel, xlabel, '%')
plot_survival_count(child_female_alive, child_female_dead, 'child female Survival Count By '+xlabel, xlabel, 'count')
plot_survival_rates(child_female_alive, child_female_dead, 'child female Survival Rates By '+xlabel, xlabel, '%')
plot_survival_count(child_male_alive, child_male_dead, 'child male Survival Count By '+xlabel, xlabel, 'count')
plot_survival_rates(child_male_alive, child_male_dead, 'child male Survival Rates By '+xlabel, xlabel, '%')

# %%
feature = []
for x in transform_df.columns:
    feature.append(x)
position = feature.index('PassengerId')
del feature[position]
position = feature.index('Survived')
del feature[position]
position = feature.index('Name')
del feature[position]
position = feature.index('Age')
del feature[position]
position = feature.index('Ticket')
del feature[position]
position = feature.index('Fare')
del feature[position]
position = feature.index('Cabin')
del feature[position]
for xlabel in feature:
    plot_survival_count(alive, dead, 'Survival Count By '+xlabel, xlabel, 'count')
    plot_survival_rates(alive, dead, 'Survival Rates By '+xlabel, xlabel, '%')
    plot_survival_count(female_alive, female_dead, 'female Survival Count By '+xlabel, xlabel, 'count')
    plot_survival_rates(female_alive, female_dead, 'female Survival Rates By '+xlabel, xlabel, '%')
    plot_survival_count(male_alive, male_dead, 'male Survival Count By '+xlabel, xlabel, 'count')
    plot_survival_rates(male_alive, male_dead, 'male Survival Rates By '+xlabel, xlabel, '%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d4ddc3f1c261> in <module>()
#       2 for x in transform_df.columns:
#       3     feature.append(x)
# ----> 4 position = feature.index('PassengerId')
#       5 del feature[position]
#       6 position = feature.index('Survived')
#
# ValueError: 'PassengerId' is not in list

# %%
AgeGroups = transform_df.groupby('AgeGroup').size().reset_index(name='count')
del AgeGroups['count']

if True:
    print("AgeGroups")
    print(AgeGroups)
# Out:
# AgeGroups
#    AgeGroup
# 0   1: 0-20
# 1  2: 21-40
# 2  3: 41-60
# 3  4: 61-80

# %%
def my_correlation(x, y):
    std_x = (x - x.mean()) / x.std(ddof=0)
    std_y = (y - y.mean()) / y.std(ddof=0)
    return (std_x * std_y).mean()

# %%
SibSp_group = transform_df.groupby('SibSp').size().reset_index(name='count')
SibSp_list = SibSp_group['SibSp']
Parch_group = transform_df.groupby('Parch').size().reset_index(name='count')
Parch_list = Parch_group['Parch']

# %%
def SibSp_Parch_Correlation(SibSp_df, Parch_df, Dead_or_Alive):

    for x in SibSp_list:
        table1 = SibSp_df[SibSp_df['SibSp']==x]
        merge_table1 = pd.merge(table1, AgeGroups, how='outer', on='AgeGroup')
        merge_table1['SibSp'].fillna(x, inplace=True)
        merge_table1[Dead_or_Alive].fillna(0, inplace=True)

        for y in Parch_list:
            table2 = Parch_df[Parch_df['Parch']==y]
            merge_table2 = pd.merge(table2, AgeGroups, how='outer', on='AgeGroup')
            merge_table2['Parch'].fillna(y, inplace=True)
            merge_table2[Dead_or_Alive].fillna(0, inplace=True)

            my_pearsons_r = my_correlation(merge_table1[Dead_or_Alive], merge_table2[Dead_or_Alive])
            if not math.isnan(my_pearsons_r):
                pearsons_r = np.corrcoef(merge_table1[Dead_or_Alive], merge_table2[Dead_or_Alive])
                print("")
                print(Dead_or_Alive+" SibSp["+str(x)+"]")
                print(Dead_or_Alive+" Parch["+str(y)+"]")
                print("my pearson's r = "+str(my_pearsons_r))
                print("vs pearson's r  = "+str(pearsons_r))

# %%
print("")
print("alive sibsp/parch correlation")
alive_SibSp = alive.groupby(['SibSp','AgeGroup']).size().reset_index(name='Alive')
alive_Parch = alive.groupby(['Parch','AgeGroup']).size().reset_index(name='Alive')
SibSp_Parch_Correlation(alive_SibSp, alive_Parch, 'Alive')
print("")
print("dead sibsp/parch correlation")
dead_SibSp = dead.groupby(['SibSp','AgeGroup']).size().reset_index(name='Dead')
dead_Parch = dead.groupby(['Parch','AgeGroup']).size().reset_index(name='Dead')
SibSp_Parch_Correlation(dead_SibSp, dead_Parch, 'Dead')
# Out:
# alive sibsp/parch correlation
#
# Alive SibSp[0]
# Alive Parch[0]
# my pearson's r = 0.9887587711204934
# vs pearson's r  = [[1.         0.98875877]
#  [0.98875877 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[1]
# my pearson's r = 0.4770347455805875
# vs pearson's r  = [[1.         0.47703475]
#  [0.47703475 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[2]
# my pearson's r = 0.6008395204224299
# vs pearson's r  = [[1.         0.60083952]
#  [0.60083952 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[3]
# my pearson's r = 0.3762313509563047
# vs pearson's r  = [[1.         0.37623135]
#  [0.37623135 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[5]
# my pearson's r = -0.12103193564896716
# vs pearson's r  = [[ 1.         -0.12103194]
#  [-0.12103194  1.        ]]
#
# Alive SibSp[1]
# Alive Parch[0]
# my pearson's r = 0.9068380007092443
# vs pearson's r  = [[1.       0.906838]
#  [0.906838 1.      ]]
#
# Alive SibSp[1]
# Alive Parch[1]
# my pearson's r = 0.712169737487593
# vs pearson's r  = [[1.         0.71216974]
#  [0.71216974 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[2]
# my pearson's r = 0.7634912097654706
# vs pearson's r  = [[1.         0.76349121]
#  [0.76349121 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[3]
# my pearson's r = 0.5819451655267582
# vs pearson's r  = [[1.         0.58194517]
#  [0.58194517 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[5]
# my pearson's r = 0.13929251917576696
# vs pearson's r  = [[1.         0.13929252]
#  [0.13929252 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[0]
# my pearson's r = 0.5235589212339481
# vs pearson's r  = [[1.         0.52355892]
#  [0.52355892 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[1]
# my pearson's r = 0.9786996945853463
# vs pearson's r  = [[1.         0.97869969]
#  [0.97869969 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[2]
# my pearson's r = 0.9648582287256698
# vs pearson's r  = [[1.         0.96485823]
#  [0.96485823 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[3]
# my pearson's r = 0.9166023347994703
# vs pearson's r  = [[1.         0.91660233]
#  [0.91660233 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[5]
# my pearson's r = 0.6657502859356828
# vs pearson's r  = [[1.         0.66575029]
#  [0.66575029 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[0]
# my pearson's r = -0.26730086912414963
# vs pearson's r  = [[ 1.         -0.26730087]
#  [-0.26730087  1.        ]]
#
# Alive SibSp[3]
# Alive Parch[1]
# my pearson's r = 0.7735449421179452
# vs pearson's r  = [[1.         0.77354494]
#  [0.77354494 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[2]
# my pearson's r = 0.7164977208318386
# vs pearson's r  = [[1.         0.71649772]
#  [0.71649772 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[3]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[5]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Alive SibSp[4]
# Alive Parch[0]
# my pearson's r = -0.2673008691241496
# vs pearson's r  = [[ 1.         -0.26730087]
#  [-0.26730087  1.        ]]
#
# Alive SibSp[4]
# Alive Parch[1]
# my pearson's r = 0.773544942117945
# vs pearson's r  = [[1.         0.77354494]
#  [0.77354494 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[2]
# my pearson's r = 0.7164977208318385
# vs pearson's r  = [[1.         0.71649772]
#  [0.71649772 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[3]
# my pearson's r = 0.8703882797784891
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[5]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# dead sibsp/parch correlation
#
# Dead SibSp[0]
# Dead Parch[0]
# my pearson's r = 0.9999577268663672
# vs pearson's r  = [[1.         0.99995773]
#  [0.99995773 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[1]
# my pearson's r = 0.5640731537928041
# vs pearson's r  = [[1.         0.56407315]
#  [0.56407315 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[2]
# my pearson's r = 0.5648171556117575
# vs pearson's r  = [[1.         0.56481716]
#  [0.56481716 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[3]
# my pearson's r = 0.6172837609800397
# vs pearson's r  = [[1.         0.61728376]
#  [0.61728376 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[4]
# my pearson's r = 0.12471015237294916
# vs pearson's r  = [[1.         0.12471015]
#  [0.12471015 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[5]
# my pearson's r = 0.05800116003480116
# vs pearson's r  = [[1.         0.05800116]
#  [0.05800116 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[6]
# my pearson's r = -0.2743629184136224
# vs pearson's r  = [[ 1.         -0.27436292]
#  [-0.27436292  1.        ]]
#
# Dead SibSp[1]
# Dead Parch[0]
# my pearson's r = 0.9943575013005902
# vs pearson's r  = [[1.        0.9943575]
#  [0.9943575 1.       ]]
#
# Dead SibSp[1]
# Dead Parch[1]
# my pearson's r = 0.6285456223444346
# vs pearson's r  = [[1.         0.62854562]
#  [0.62854562 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[2]
# my pearson's r = 0.6111364398462189
# vs pearson's r  = [[1.         0.61113644]
#  [0.61113644 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[3]
# my pearson's r = 0.6530209485014041
# vs pearson's r  = [[1.         0.65302095]
#  [0.65302095 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[4]
# my pearson's r = 0.21913822282003376
# vs pearson's r  = [[1.         0.21913822]
#  [0.21913822 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[5]
# my pearson's r = 0.11748240393953395
# vs pearson's r  = [[1.        0.1174824]
#  [0.1174824 1.       ]]
#
# Dead SibSp[1]
# Dead Parch[6]
# my pearson's r = -0.21087661141226716
# vs pearson's r  = [[ 1.         -0.21087661]
#  [-0.21087661  1.        ]]
#
# Dead SibSp[2]
# Dead Parch[0]
# my pearson's r = 0.987284437921566
# vs pearson's r  = [[1.         0.98728444]
#  [0.98728444 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[1]
# my pearson's r = 0.6928819385779112
# vs pearson's r  = [[1.         0.69288194]
#  [0.69288194 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[2]
# my pearson's r = 0.6889821949994965
# vs pearson's r  = [[1.         0.68898219]
#  [0.68898219 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[3]
# my pearson's r = 0.7300956427599692
# vs pearson's r  = [[1.         0.73009564]
#  [0.73009564 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[4]
# my pearson's r = 0.2815939526783592
# vs pearson's r  = [[1.         0.28159395]
#  [0.28159395 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[5]
# my pearson's r = 0.21677112584136196
# vs pearson's r  = [[1.         0.21677113]
#  [0.21677113 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[6]
# my pearson's r = -0.11496024978590216
# vs pearson's r  = [[ 1.         -0.11496025]
#  [-0.11496025  1.        ]]
#
# Dead SibSp[3]
# Dead Parch[0]
# my pearson's r = 0.06607341847849471
# vs pearson's r  = [[1.         0.06607342]
#  [0.06607342 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[1]
# my pearson's r = 0.8248711239545368
# vs pearson's r  = [[1.         0.82487112]
#  [0.82487112 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[2]
# my pearson's r = 0.8565861529340607
# vs pearson's r  = [[1.         0.85658615]
#  [0.85658615 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[3]
# my pearson's r = 0.816496580927726
# vs pearson's r  = [[1.         0.81649658]
#  [0.81649658 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[4]
# my pearson's r = 0.8660254037844386
# vs pearson's r  = [[1.        0.8660254]
#  [0.8660254 1.       ]]
#
# Dead SibSp[3]
# Dead Parch[5]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[3]
# Dead Parch[6]
# my pearson's r = 0.9428090415820635
# vs pearson's r  = [[1.         0.94280904]
#  [0.94280904 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[0]
# my pearson's r = -0.2668012844979861
# vs pearson's r  = [[ 1.         -0.26680128]
#  [-0.26680128  1.        ]]
#
# Dead SibSp[4]
# Dead Parch[1]
# my pearson's r = 0.6186217814352355
# vs pearson's r  = [[1.         0.61862178]
#  [0.61862178 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[2]
# my pearson's r = 0.6375767130633382
# vs pearson's r  = [[1.         0.63757671]
#  [0.63757671 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[3]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[4]
# my pearson's r = 0.8164965809277259
# vs pearson's r  = [[1.         0.81649658]
#  [0.81649658 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[5]
# my pearson's r = 0.9428090415820635
# vs pearson's r  = [[1.         0.94280904]
#  [0.94280904 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[6]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[5]
# Dead Parch[0]
# my pearson's r = -0.2668012844979861
# vs pearson's r  = [[ 1.         -0.26680128]
#  [-0.26680128  1.        ]]
#
# Dead SibSp[5]
# Dead Parch[1]
# my pearson's r = 0.6186217814352355
# vs pearson's r  = [[1.         0.61862178]
#  [0.61862178 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[2]
# my pearson's r = 0.6375767130633382
# vs pearson's r  = [[1.         0.63757671]
#  [0.63757671 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[3]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[4]
# my pearson's r = 0.8164965809277259
# vs pearson's r  = [[1.         0.81649658]
#  [0.81649658 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[5]
# my pearson's r = 0.9428090415820635
# vs pearson's r  = [[1.         0.94280904]
#  [0.94280904 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[6]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[8]
# Dead Parch[0]
# my pearson's r = 0.9847442318643012
# vs pearson's r  = [[1.         0.98474423]
#  [0.98474423 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[1]
# my pearson's r = 0.6061308925191604
# vs pearson's r  = [[1.         0.60613089]
#  [0.60613089 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[2]
# my pearson's r = 0.6437295862716259
# vs pearson's r  = [[1.         0.64372959]
#  [0.64372959 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[3]
# my pearson's r = 0.7035264706814485
# vs pearson's r  = [[1.         0.70352647]
#  [0.70352647 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[4]
# my pearson's r = 0.14213381090374028
# vs pearson's r  = [[1.         0.14213381]
#  [0.14213381 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[5]
# my pearson's r = 0.16412198797244365
# vs pearson's r  = [[1.         0.16412199]
#  [0.16412199 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[6]
# my pearson's r = -0.17407765595569782
# vs pearson's r  = [[ 1.         -0.17407766]
#  [-0.17407766  1.        ]]

# %%
print("")
print("female alive sibsp/parch correlation")
female_alive_SibSp = female_alive.groupby(['SibSp','AgeGroup']).size().reset_index(name='Alive')
female_alive_Parch = female_alive.groupby(['Parch','AgeGroup']).size().reset_index(name='Alive')
SibSp_Parch_Correlation(female_alive_SibSp, female_alive_Parch, 'Alive')
print("")
print("female dead sibsp/parch correlation")
female_dead_SibSp = female_dead.groupby(['SibSp','AgeGroup']).size().reset_index(name='Dead')
female_dead_Parch = female_dead.groupby(['Parch','AgeGroup']).size().reset_index(name='Dead')
SibSp_Parch_Correlation(female_dead_SibSp, female_dead_Parch, 'Dead')
print("")
print("male alive sibsp/parch correlation")
male_alive_SibSp = male_alive.groupby(['SibSp','AgeGroup']).size().reset_index(name='Alive')
male_alive_Parch = male_alive.groupby(['Parch','AgeGroup']).size().reset_index(name='Alive')
SibSp_Parch_Correlation(male_alive_SibSp, male_alive_Parch, 'Alive')
print("")
print("male dead sibsp/parch correlation")
male_dead_SibSp = male_dead.groupby(['SibSp','AgeGroup']).size().reset_index(name='Dead')
male_dead_Parch = male_dead.groupby(['Parch','AgeGroup']).size().reset_index(name='Dead')
SibSp_Parch_Correlation(male_dead_SibSp, male_dead_Parch, 'Dead')
# Out:
# female alive sibsp/parch correlation
#
# Alive SibSp[0]
# Alive Parch[0]
# my pearson's r = 0.9891738347633446
# vs pearson's r  = [[1.         0.98917383]
#  [0.98917383 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[1]
# my pearson's r = 0.7666345408999917
# vs pearson's r  = [[1.         0.76663454]
#  [0.76663454 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[2]
# my pearson's r = 0.8481208445593957
# vs pearson's r  = [[1.         0.84812084]
#  [0.84812084 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[3]
# my pearson's r = 0.4139929005301109
# vs pearson's r  = [[1.        0.4139929]
#  [0.4139929 1.       ]]
#
# Alive SibSp[0]
# Alive Parch[5]
# my pearson's r = -0.07789891828399331
# vs pearson's r  = [[ 1.         -0.07789892]
#  [-0.07789892  1.        ]]
#
# Alive SibSp[1]
# Alive Parch[0]
# my pearson's r = 0.9909042712117774
# vs pearson's r  = [[1.         0.99090427]
#  [0.99090427 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[1]
# my pearson's r = 0.7652547373822196
# vs pearson's r  = [[1.         0.76525474]
#  [0.76525474 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[2]
# my pearson's r = 0.8086847188328241
# vs pearson's r  = [[1.         0.80868472]
#  [0.80868472 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[3]
# my pearson's r = 0.35760549169482864
# vs pearson's r  = [[1.         0.35760549]
#  [0.35760549 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[5]
# my pearson's r = -0.1304309301452049
# vs pearson's r  = [[ 1.         -0.13043093]
#  [-0.13043093  1.        ]]
#
# Alive SibSp[2]
# Alive Parch[0]
# my pearson's r = 0.5396988179698162
# vs pearson's r  = [[1.         0.53969882]
#  [0.53969882 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[1]
# my pearson's r = 0.8977894101425634
# vs pearson's r  = [[1.         0.89778941]
#  [0.89778941 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[2]
# my pearson's r = 0.9408929189489628
# vs pearson's r  = [[1.         0.94089292]
#  [0.94089292 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[3]
# my pearson's r = 0.9506541513652699
# vs pearson's r  = [[1.         0.95065415]
#  [0.95065415 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[5]
# my pearson's r = 0.700140042014005
# vs pearson's r  = [[1.         0.70014004]
#  [0.70014004 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[0]
# my pearson's r = -0.2207581684239791
# vs pearson's r  = [[ 1.         -0.22075817]
#  [-0.22075817  1.        ]]
#
# Alive SibSp[3]
# Alive Parch[1]
# my pearson's r = 0.44356281120003155
# vs pearson's r  = [[1.         0.44356281]
#  [0.44356281 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[2]
# my pearson's r = 0.44795462930645247
# vs pearson's r  = [[1.         0.44795463]
#  [0.44795463 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[3]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Alive SibSp[3]
# Alive Parch[5]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Alive SibSp[4]
# Alive Parch[0]
# my pearson's r = -0.2207581684239791
# vs pearson's r  = [[ 1.         -0.22075817]
#  [-0.22075817  1.        ]]
#
# Alive SibSp[4]
# Alive Parch[1]
# my pearson's r = 0.44356281120003155
# vs pearson's r  = [[1.         0.44356281]
#  [0.44356281 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[2]
# my pearson's r = 0.44795462930645247
# vs pearson's r  = [[1.         0.44795463]
#  [0.44795463 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[3]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[5]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# female dead sibsp/parch correlation
#
# Dead SibSp[0]
# Dead Parch[0]
# my pearson's r = 0.9967765130667732
# vs pearson's r  = [[1.         0.99677651]
#  [0.99677651 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[1]
# my pearson's r = 0.9268776714727991
# vs pearson's r  = [[1.         0.92687767]
#  [0.92687767 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[2]
# my pearson's r = 0.6437600871214899
# vs pearson's r  = [[1.         0.64376009]
#  [0.64376009 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[3]
# my pearson's r = -0.08523690424912794
# vs pearson's r  = [[ 1.        -0.0852369]
#  [-0.0852369  1.       ]]
#
# Dead SibSp[0]
# Dead Parch[4]
# my pearson's r = 0.7381732441968658
# vs pearson's r  = [[1.         0.73817324]
#  [0.73817324 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[5]
# my pearson's r = 0.40062169330042835
# vs pearson's r  = [[1.         0.40062169]
#  [0.40062169 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[6]
# my pearson's r = -0.08523690424912794
# vs pearson's r  = [[ 1.        -0.0852369]
#  [-0.0852369  1.       ]]
#
# Dead SibSp[1]
# Dead Parch[0]
# my pearson's r = 0.9879556074318532
# vs pearson's r  = [[1.         0.98795561]
#  [0.98795561 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[1]
# my pearson's r = 0.893969271006563
# vs pearson's r  = [[1.         0.89396927]
#  [0.89396927 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[2]
# my pearson's r = 0.5879644709297929
# vs pearson's r  = [[1.         0.58796447]
#  [0.58796447 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[3]
# my pearson's r = -0.14797908710009705
# vs pearson's r  = [[ 1.         -0.14797909]
#  [-0.14797909  1.        ]]
#
# Dead SibSp[1]
# Dead Parch[4]
# my pearson's r = 0.6834861261734086
# vs pearson's r  = [[1.         0.68348613]
#  [0.68348613 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[5]
# my pearson's r = 0.3348780839670361
# vs pearson's r  = [[1.         0.33487808]
#  [0.33487808 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[6]
# my pearson's r = -0.14797908710009705
# vs pearson's r  = [[ 1.         -0.14797909]
#  [-0.14797909  1.        ]]
#
# Dead SibSp[2]
# Dead Parch[0]
# my pearson's r = 0.42194449009401347
# vs pearson's r  = [[1.         0.42194449]
#  [0.42194449 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[1]
# my pearson's r = 0.7063224140220168
# vs pearson's r  = [[1.         0.70632241]
#  [0.70632241 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[2]
# my pearson's r = 0.9590268199959644
# vs pearson's r  = [[1.         0.95902682]
#  [0.95902682 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[3]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[4]
# my pearson's r = 0.9045340337332908
# vs pearson's r  = [[1.         0.90453403]
#  [0.90453403 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[5]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[2]
# Dead Parch[6]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[0]
# my pearson's r = 0.6222577206414517
# vs pearson's r  = [[1.         0.62225772]
#  [0.62225772 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[1]
# my pearson's r = 0.852879332839356
# vs pearson's r  = [[1.         0.85287933]
#  [0.85287933 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[2]
# my pearson's r = 0.9960575442798578
# vs pearson's r  = [[1.         0.99605754]
#  [0.99605754 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[3]
# my pearson's r = 0.7276068751089989
# vs pearson's r  = [[1.         0.72760688]
#  [0.72760688 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[4]
# my pearson's r = 0.9801960588196068
# vs pearson's r  = [[1.         0.98019606]
#  [0.98019606 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[5]
# my pearson's r = 0.9710607611177228
# vs pearson's r  = [[1.         0.97106076]
#  [0.97106076 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[6]
# my pearson's r = 0.7276068751089989
# vs pearson's r  = [[1.         0.72760688]
#  [0.72760688 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[0]
# my pearson's r = -0.07087387592709371
# vs pearson's r  = [[ 1.         -0.07087388]
#  [-0.07087388  1.        ]]
#
# Dead SibSp[4]
# Dead Parch[1]
# my pearson's r = 0.27050089040022973
# vs pearson's r  = [[1.         0.27050089]
#  [0.27050089 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[2]
# my pearson's r = 0.7011695914588868
# vs pearson's r  = [[1.         0.70116959]
#  [0.70116959 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[3]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[4]
# Dead Parch[4]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[5]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[6]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[5]
# Dead Parch[0]
# my pearson's r = -0.07087387592709371
# vs pearson's r  = [[ 1.         -0.07087388]
#  [-0.07087388  1.        ]]
#
# Dead SibSp[5]
# Dead Parch[1]
# my pearson's r = 0.27050089040022973
# vs pearson's r  = [[1.         0.27050089]
#  [0.27050089 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[2]
# my pearson's r = 0.7011695914588868
# vs pearson's r  = [[1.         0.70116959]
#  [0.70116959 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[3]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[5]
# Dead Parch[4]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[5]
# my pearson's r = 0.8703882797784894
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[6]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
# Dead SibSp[8]
# Dead Parch[0]
# my pearson's r = -0.07087387592709365
# vs pearson's r  = [[ 1.         -0.07087388]
#  [-0.07087388  1.        ]]
#
# Dead SibSp[8]
# Dead Parch[1]
# my pearson's r = 0.2705008904002297
# vs pearson's r  = [[1.         0.27050089]
#  [0.27050089 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[2]
# my pearson's r = 0.7011695914588867
# vs pearson's r  = [[1.         0.70116959]
#  [0.70116959 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[3]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[8]
# Dead Parch[4]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[5]
# my pearson's r = 0.8703882797784891
# vs pearson's r  = [[1.         0.87038828]
#  [0.87038828 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[6]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# male alive sibsp/parch correlation
#
# Alive SibSp[0]
# Alive Parch[0]
# my pearson's r = 0.981931057714416
# vs pearson's r  = [[1.         0.98193106]
#  [0.98193106 1.        ]]
#
# Alive SibSp[0]
# Alive Parch[1]
# my pearson's r = -0.017235864701337172
# vs pearson's r  = [[ 1.         -0.01723586]
#  [-0.01723586  1.        ]]
#
# Alive SibSp[0]
# Alive Parch[2]
# my pearson's r = -0.08682990313019287
# vs pearson's r  = [[ 1.        -0.0868299]
#  [-0.0868299  1.       ]]
#
# Alive SibSp[1]
# Alive Parch[0]
# my pearson's r = 0.13994538757359545
# vs pearson's r  = [[1.         0.13994539]
#  [0.13994539 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[1]
# my pearson's r = 0.9229623653875081
# vs pearson's r  = [[1.         0.92296237]
#  [0.92296237 1.        ]]
#
# Alive SibSp[1]
# Alive Parch[2]
# my pearson's r = 0.8868104355148353
# vs pearson's r  = [[1.         0.88681044]
#  [0.88681044 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[0]
# my pearson's r = 0.4880038317488332
# vs pearson's r  = [[1.         0.48800383]
#  [0.48800383 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[1]
# my pearson's r = 0.4558833088075066
# vs pearson's r  = [[1.         0.45588331]
#  [0.45588331 1.        ]]
#
# Alive SibSp[2]
# Alive Parch[2]
# my pearson's r = 0.38235955645093633
# vs pearson's r  = [[1.         0.38235956]
#  [0.38235956 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[0]
# my pearson's r = -0.35244721181860184
# vs pearson's r  = [[ 1.         -0.35244721]
#  [-0.35244721  1.        ]]
#
# Alive SibSp[4]
# Alive Parch[1]
# my pearson's r = 0.9837481926898827
# vs pearson's r  = [[1.         0.98374819]
#  [0.98374819 1.        ]]
#
# Alive SibSp[4]
# Alive Parch[2]
# my pearson's r = 0.9941348467724342
# vs pearson's r  = [[1.         0.99413485]
#  [0.99413485 1.        ]]
#
# male dead sibsp/parch correlation
#
# Dead SibSp[0]
# Dead Parch[0]
# my pearson's r = 0.999978788038889
# vs pearson's r  = [[1.         0.99997879]
#  [0.99997879 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[1]
# my pearson's r = 0.3246244222775234
# vs pearson's r  = [[1.         0.32462442]
#  [0.32462442 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[2]
# my pearson's r = 0.6136499537408917
# vs pearson's r  = [[1.         0.61364995]
#  [0.61364995 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[3]
# my pearson's r = -0.2908088109932332
# vs pearson's r  = [[ 1.         -0.29080881]
#  [-0.29080881  1.        ]]
#
# Dead SibSp[0]
# Dead Parch[4]
# my pearson's r = 0.6049677743697206
# vs pearson's r  = [[1.         0.60496777]
#  [0.60496777 1.        ]]
#
# Dead SibSp[0]
# Dead Parch[5]
# my pearson's r = -0.2908088109932332
# vs pearson's r  = [[ 1.         -0.29080881]
#  [-0.29080881  1.        ]]
#
# Dead SibSp[1]
# Dead Parch[0]
# my pearson's r = 0.9962217406169325
# vs pearson's r  = [[1.         0.99622174]
#  [0.99622174 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[1]
# my pearson's r = 0.398204844504095
# vs pearson's r  = [[1.         0.39820484]
#  [0.39820484 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[2]
# my pearson's r = 0.654959052175589
# vs pearson's r  = [[1.         0.65495905]
#  [0.65495905 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[3]
# my pearson's r = -0.23240482496553164
# vs pearson's r  = [[ 1.         -0.23240482]
#  [-0.23240482  1.        ]]
#
# Dead SibSp[1]
# Dead Parch[4]
# my pearson's r = 0.6410773883285726
# vs pearson's r  = [[1.         0.64107739]
#  [0.64107739 1.        ]]
#
# Dead SibSp[1]
# Dead Parch[5]
# my pearson's r = -0.23240482496553164
# vs pearson's r  = [[ 1.         -0.23240482]
#  [-0.23240482  1.        ]]
#
# Dead SibSp[2]
# Dead Parch[0]
# my pearson's r = 0.9971206108944721
# vs pearson's r  = [[1.         0.99712061]
#  [0.99712061 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[1]
# my pearson's r = 0.3088749370021377
# vs pearson's r  = [[1.         0.30887494]
#  [0.30887494 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[2]
# my pearson's r = 0.5789703028396603
# vs pearson's r  = [[1.        0.5789703]
#  [0.5789703 1.       ]]
#
# Dead SibSp[2]
# Dead Parch[3]
# my pearson's r = -0.32659863237109044
# vs pearson's r  = [[ 1.         -0.32659863]
#  [-0.32659863  1.        ]]
#
# Dead SibSp[2]
# Dead Parch[4]
# my pearson's r = 0.565685424949238
# vs pearson's r  = [[1.         0.56568542]
#  [0.56568542 1.        ]]
#
# Dead SibSp[2]
# Dead Parch[5]
# my pearson's r = -0.32659863237109044
# vs pearson's r  = [[ 1.         -0.32659863]
#  [-0.32659863  1.        ]]
#
# Dead SibSp[3]
# Dead Parch[0]
# my pearson's r = -0.28481660189504165
# vs pearson's r  = [[ 1.        -0.2848166]
#  [-0.2848166  1.       ]]
#
# Dead SibSp[3]
# Dead Parch[1]
# my pearson's r = 0.7618400593644639
# vs pearson's r  = [[1.         0.76184006]
#  [0.76184006 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[2]
# my pearson's r = 0.5757575757575758
# vs pearson's r  = [[1.         0.57575758]
#  [0.57575758 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[3]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[3]
# Dead Parch[4]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[3]
# Dead Parch[5]
# my pearson's r = 1.0
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[4]
# Dead Parch[0]
# my pearson's r = -0.28481660189504165
# vs pearson's r  = [[ 1.        -0.2848166]
#  [-0.2848166  1.       ]]
#
# Dead SibSp[4]
# Dead Parch[1]
# my pearson's r = 0.7618400593644641
# vs pearson's r  = [[1.         0.76184006]
#  [0.76184006 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[2]
# my pearson's r = 0.5757575757575758
# vs pearson's r  = [[1.         0.57575758]
#  [0.57575758 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[3]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[4]
# Dead Parch[4]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[4]
# Dead Parch[5]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[5]
# Dead Parch[0]
# my pearson's r = -0.28481660189504165
# vs pearson's r  = [[ 1.        -0.2848166]
#  [-0.2848166  1.       ]]
#
# Dead SibSp[5]
# Dead Parch[1]
# my pearson's r = 0.761840059364464
# vs pearson's r  = [[1.         0.76184006]
#  [0.76184006 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[2]
# my pearson's r = 0.5757575757575759
# vs pearson's r  = [[1.         0.57575758]
#  [0.57575758 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[3]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[5]
# Dead Parch[4]
# my pearson's r = 0.5773502691896257
# vs pearson's r  = [[1.         0.57735027]
#  [0.57735027 1.        ]]
#
# Dead SibSp[5]
# Dead Parch[5]
# my pearson's r = 1.0000000000000002
# vs pearson's r  = [[1. 1.]
#  [1. 1.]]
#
# Dead SibSp[8]
# Dead Parch[0]
# my pearson's r = 0.9480799957231332
# vs pearson's r  = [[1.      0.94808]
#  [0.94808 1.     ]]
#
# Dead SibSp[8]
# Dead Parch[1]
# my pearson's r = 0.520126331736996
# vs pearson's r  = [[1.         0.52012633]
#  [0.52012633 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[2]
# my pearson's r = 0.8142441722754185
# vs pearson's r  = [[1.         0.81424417]
#  [0.81424417 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[3]
# my pearson's r = 0.0
# vs pearson's r  = [[1. 0.]
#  [0. 1.]]
#
# Dead SibSp[8]
# Dead Parch[4]
# my pearson's r = 0.8164965809277261
# vs pearson's r  = [[1.         0.81649658]
#  [0.81649658 1.        ]]
#
# Dead SibSp[8]
# Dead Parch[5]
# my pearson's r = 0.0
# vs pearson's r  = [[1. 0.]
#  [0. 1.]]

# %%
print("")
print("alive SibSp/Parch pearson's r")
sns.jointplot(data=alive, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()
print("")
print("dead SibSp/Parch pearson's r")
sns.jointplot(data=dead, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()
# Out:
# alive SibSp/Parch pearson's r
# dead SibSp/Parch pearson's r

# %%
print("")
print("female alive SibSp/Parch pearson's r")
sns.jointplot(data=female_alive, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()
print("")
print("female dead SibSp/Parch pearson's r")
sns.jointplot(data=female_dead, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()
print("")
print("male alive SibSp/Parch pearson's r")
sns.jointplot(data=male_alive, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()
print("")
print("male dead SibSp/Parch pearson's r")
sns.jointplot(data=male_dead, x='SibSp', y='Parch', kind='reg', color='g')
plt.show()
# Out:
# female alive SibSp/Parch pearson's r
# female dead SibSp/Parch pearson's r
# male alive SibSp/Parch pearson's r
# male dead SibSp/Parch pearson's r
